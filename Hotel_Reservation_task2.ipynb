# %% [markdown]
# <a href="https://colab.research.google.com/github/Fares-mohamedd/Cellula_Technology_Intern/blob/main/Hotel_Reservation_task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import pickle

# %%
df=pd.read_csv('/content/first inten project.csv')
print(df.head())
# Out:
#   Booking_ID  number of adults  number of children  number of weekend nights  \
# 0   INN00001                 1                   1                         2
# 1   INN00002                 1                   0                         1
# 2   INN00003                 2                   1                         1
# 3   INN00004                 1                   0                         0
# 4   INN00005                 1                   0                         1
#
#    number of week nights  type of meal  car parking space    room type  \
# 0                      5   Meal Plan 1                  0  Room_Type 1
# 1                      3  Not Selected                  0  Room_Type 1
# 2                      3   Meal Plan 1                  0  Room_Type 1
# 3                      2   Meal Plan 1                  0  Room_Type 1
# 4                      2  Not Selected                  0  Room_Type 1
#
#    lead time market segment type  repeated  P-C  P-not-C  average price   \
# ...

# %%
df.drop(['Booking_ID'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36285 entries, 0 to 36284
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   number of adults          36285 non-null  int64
#  1   number of children        36285 non-null  int64
#  2   number of weekend nights  36285 non-null  int64
#  3   number of week nights     36285 non-null  int64
#  4   type of meal              36285 non-null  object
#  5   car parking space         36285 non-null  int64
#  6   room type                 36285 non-null  object
#  7   lead time                 36285 non-null  int64
#  8   market segment type       36285 non-null  object
#  9   repeated                  36285 non-null  int64
#  10  P-C                       36285 non-null  int64
#  11  P-not-C                   36285 non-null  int64
#  12  average price             36285 non-null  float64
#  13  special requests          36285 non-null  int64
# ...

# %% [markdown]
# # Data Preprocessing

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['lead time'])
plt.title('Box plot of lead time')
# Out:
# Text(0.5, 1.0, 'Box plot of lead time')

# %%
Q1 = df['lead time'].quantile(0.25)
Q3 = df['lead time'].quantile(0.75)
IQR = Q3 - Q1
outliers = (df['lead time'] < Q1 - 1.5 * IQR) | (df['lead time'] > Q3 + 1.5 * IQR)
df = df[~outliers]
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['lead time'])
plt.title('Box plot of lead time after removing outliers')
# Out:
# Text(0.5, 1.0, 'Box plot of lead time after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['average price '])
plt.title('Box plot of average price')
# Out:
# Text(0.5, 1.0, 'Box plot of average price')

# %%
Q1 = df['average price '].quantile(0.25)
Q3 = df['average price '].quantile(0.75)
IQR = Q3 - Q1
outliers = (df['average price '] < Q1 - 1.5 * IQR) | (df['average price '] > Q3 + 1.5 * IQR)
df = df[~outliers]
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['average price '])
plt.title('Box plot of average price after removing outliers')
# Out:
# Text(0.5, 1.0, 'Box plot of average price after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['number of adults'])
plt.title('Box plot of number of adults')
# Out:
# Text(0.5, 1.0, 'Box plot of number of adults')

# %%
#Q1 = df['number of adults'].quantile(0.25)
#Q3 = df['number of adults'].quantile(0.75)
#IQR = Q3 - Q1
#outliers = (df['number of adults'] < Q1 - 1.5 * IQR) | (df['number of adults'] > Q3 + 1.5 * IQR)
#df = df[~outliers]
#plt.figure(figsize=(12, 6))
#sns.boxplot(y=df['number of adults'])
#plt.title('Box plot of number of adults after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['number of children'])
plt.title('Box plot of number of children')
# Out:
# Text(0.5, 1.0, 'Box plot of number of children')

# %%
Q1 = df['number of children'].quantile(0.25)
Q3 = df['number of children'].quantile(0.75)
IQR = Q3 - Q1
outliers = (df['number of children'] < Q1 - 1.5 * IQR) | (df['number of children'] > Q3 + 1.5 * IQR)
df = df[~outliers]
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['number of children'])
plt.title('Box plot of number of children after removing outliers')
# Out:
# Text(0.5, 1.0, 'Box plot of number of children after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['number of weekend nights'])
plt.title('Box plot of number of weekend nights')
# Out:
# Text(0.5, 1.0, 'Box plot of number of weekend nights')

# %%
Q1 = df['number of weekend nights'].quantile(0.25)
Q3 = df['number of weekend nights'].quantile(0.75)
IQR = Q3 - Q1
outliers = (df['number of weekend nights'] < Q1 - 1.5 * IQR) | (df['number of weekend nights'] > Q3 + 1.5 * IQR)
df = df[~outliers]
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['number of weekend nights'])
plt.title('Box plot of number of weekend nights after removing outliers')
# Out:
# Text(0.5, 1.0, 'Box plot of number of weekend nights after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['number of week nights'])
plt.title('Box plot of number of week nights')
# Out:
# Text(0.5, 1.0, 'Box plot of number of week nights')

# %%
Q1 = df['number of week nights'].quantile(0.25)
Q3 = df['number of week nights'].quantile(0.75)
IQR = Q3 - Q1
outliers = (df['number of week nights'] < Q1 - 1.5 * IQR) | (df['number of week nights'] > Q3 + 1.5 * IQR)
df = df[~outliers]
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['number of week nights'])
plt.title('Box plot of number of week nights after removing outliers')
# Out:
# Text(0.5, 1.0, 'Box plot of number of week nights after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['type of meal'])
plt.title('Box plot of type of meal')
# Out:
# Text(0.5, 1.0, 'Box plot of type of meal')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['car parking space'])
plt.title('Box plot of car parking space')
# Out:
# Text(0.5, 1.0, 'Box plot of car parking space')

# %%
#Q1 = df['car parking space'].quantile(0.25)
#Q3 = df['car parking space'].quantile(0.75)
#IQR = Q3 - Q1
#outliers = (df['car parking space'] < Q1 - 1.5 * IQR) | (df['car parking space'] > Q3 + 1.5 * IQR)
#df = df[~outliers]
#plt.figure(figsize=(12, 6))
#sns.boxplot(y=df['car parking space'])
#plt.title('Box plot of car parking space after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['room type'])
plt.title('Box plot of room type')
# Out:
# Text(0.5, 1.0, 'Box plot of room type')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['market segment type'])
plt.title('Box plot of market segment type')
# Out:
# Text(0.5, 1.0, 'Box plot of market segment type')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['repeated'])
plt.title('Box plot of repeated')
# Out:
# Text(0.5, 1.0, 'Box plot of repeated')

# %%
#Q1 = df['repeated'].quantile(0.25)
#Q3 = df['repeated'].quantile(0.75)
#IQR = Q3 - Q1
#outliers = (df['repeated'] < Q1 - 1.5 * IQR) | (df['repeated'] > Q3 + 1.5 * IQR)
#df = df[~outliers]
#plt.figure(figsize=(12, 6))
#sns.boxplot(y=df['repeated'])
#plt.title('Box plot of repeated after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['P-C'])
plt.title('Box plot of P-C')
# Out:
# Text(0.5, 1.0, 'Box plot of P-C')

# %%
Q1 = df['P-C'].quantile(0.25)
Q3 = df['P-C'].quantile(0.75)
IQR = Q3 - Q1
outliers = (df['P-C'] < Q1 - 1.5 * IQR) | (df['P-C'] > Q3 + 1.5 * IQR)
df = df[~outliers]
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['P-C'])
plt.title('Box plot of P-C after removing outliers')
# Out:
# Text(0.5, 1.0, 'Box plot of P-C after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['P-not-C'])
plt.title('Box plot of P-not-C')
# Out:
# Text(0.5, 1.0, 'Box plot of P-not-C')

# %%
Q1 = df['P-not-C'].quantile(0.25)
Q3 = df['P-not-C'].quantile(0.75)
IQR = Q3 - Q1
outliers = (df['P-not-C'] < Q1 - 1.5 * IQR) | (df['P-not-C'] > Q3 + 1.5 * IQR)
df = df[~outliers]
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['P-not-C'])
plt.title('Box plot of P-not-C after removing outliers')
# Out:
# Text(0.5, 1.0, 'Box plot of P-not-C after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['special requests'])
plt.title('Box plot of special requests ')
# Out:
# Text(0.5, 1.0, 'Box plot of special requests ')

# %%
#Q1 = df['special requests'].quantile(0.25)
#Q3 = df['special requests'].quantile(0.75)
#IQR = Q3 - Q1
#outliers = (df['special requests'] < Q1 - 1.5 * IQR) | (df['special requests'] > Q3 + 1.5 * IQR)
#df = df[~outliers]
#plt.figure(figsize=(12, 6))
#sns.boxplot(y=df['special requests'])
#plt.title('Box plot of special requests after removing outliers')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['booking status'])
plt.title('Box plot of booking status')
# Out:
# Text(0.5, 1.0, 'Box plot of booking status')

# %%
df.drop(['date of reservation'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30195 entries, 1 to 36284
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   number of adults          30195 non-null  int64
#  1   number of children        30195 non-null  int64
#  2   number of weekend nights  30195 non-null  int64
#  3   number of week nights     30195 non-null  int64
#  4   type of meal              30195 non-null  object
#  5   car parking space         30195 non-null  int64
#  6   room type                 30195 non-null  object
#  7   lead time                 30195 non-null  int64
#  8   market segment type       30195 non-null  object
#  9   repeated                  30195 non-null  int64
#  10  P-C                       30195 non-null  int64
#  11  P-not-C                   30195 non-null  int64
#  12  average price             30195 non-null  float64
#  13  special requests          30195 non-null  int64
# ...

# %%
#from pycaret.classification import *
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
for col in df.columns:
   print(f'{col}')
   print(df[col].unique())
   print('='*75)
# Out:
# number of adults
# [1 3 2 4]
# ...
# number of children
# [0]
# ...
# number of weekend nights
# [1 0 2 3 4]
# ...
# number of week nights
# [3 2 5 0 1 4 6]
# ...
# type of meal
# ['Not Selected' 'Meal Plan 1' 'Meal Plan 2']
# ...
# car parking space
# [0 1]
# ...
# room type
# ['Room_Type 1' 'Room_Type 4' 'Room_Type 5' 'Room_Type 2' 'Room_Type 6'
#  'Room_Type 7' 'Room_Type 3']
# ...
# lead time
# [  5 211  48  83  44   0  35  30  95  47 256   1  99  12 122   2  37 130
#   60  56   3 107  72  23  34 289 247 186  64  96  41  55 146  32  57   7
#  124 169   6  51  13 100 139 117  39  86  19 192 179  26  74 143 177  18
#  267 155  46 128  20  40 196 188 110  68  73  92 171 118 189  16  24   8
#   10 182 123 286 148  14  85  25  28  80  11  82  27 245 266 112  88  69
#  273  97  31  62 197 280 185 160 104  22 109 126  81  54  15 161  87 127
#  156  58 111  17   4 195 119  59 103  70  76  49  36  79  21  33 164  78
#  152  43 102  71 209  93  53 239  45 167 113 166 174  61 151  84  67 282
# ...

# %% [markdown]
# # One-hot encode categorical features

# %% [markdown]
# Handling Categorical Variables -
# Avoiding Ordinal Relationships -
# Improved Model Performance -
# Scalability

# %%
hot=['number of adults', 'number of children', 'number of weekend nights', 'number of week nights', 'type of meal', 'car parking space',  'room type', 'market segment type', 'repeated', 'P-C','P-not-C', 'special requests']
df=pd.get_dummies(columns=hot,data=df)

# %%
X=df.drop('booking status',axis=1)
Y=df['booking status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# DATA SCALING

# %%
#robust_scaler = RobustScaler()

#X_train = robust_scaler.fit_transform(X_train)
#X_test=robust_scaler.fit_transform(X_test)

# %% [markdown]
# # MODELING

# %%
model=RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8741513495611857

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     Canceled       0.84      0.75      0.79      1941
# Not_Canceled       0.89      0.93      0.91      4098
#
#     accuracy                           0.87      6039
#    macro avg       0.86      0.84      0.85      6039
# weighted avg       0.87      0.87      0.87      6039

# %%
rf_model = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=25, max_features='sqrt',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0,
                       n_estimators=500, n_jobs=-1, oob_score=False,
                       random_state=8389, verbose=0, warm_start=False)
rf_model.fit(X_train, y_train)
y_pred=rf_model.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_pred,y_test))
# Out:
# 0.876635204504057
#               precision    recall  f1-score   support
#
#     Canceled       0.76      0.84      0.80      1738
# Not_Canceled       0.93      0.89      0.91      4301
#
#     accuracy                           0.88      6039
#    macro avg       0.84      0.87      0.85      6039
# weighted avg       0.88      0.88      0.88      6039
